# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Pragati\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Fetching the dataset

# %%
data=pd.read_csv("Processed_Flipdata - Processed_Flipdata.csv")

# %%
data
# Out:
#      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 0             0        Infinix SMART 7     Night Black      64    4      6000
# 1             1        Infinix SMART 7      Azure Blue      64    4      6000
# 2             2           MOTOROLA G32    Mineral Gray     128    8      5000
# 3             3               POCO C50      Royal Blue      32    2      5000
# 4             4        Infinix HOT 30i        Marigold     128    8      5000
# ..          ...                    ...             ...     ...  ...       ...
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
# ...

# %% [markdown]
# # Preprocessing of data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     541 non-null    int64
#  1   Model          541 non-null    object
#  2   Colour         541 non-null    object
#  3   Memory         541 non-null    int64
#  4   RAM            541 non-null    int64
#  5   Battery_       541 non-null    int64
#  6   Rear Camera    541 non-null    object
#  7   Front Camera   541 non-null    object
#  8   AI Lens        541 non-null    int64
#  9   Mobile Height  541 non-null    float64
#  10  Processor_     541 non-null    object
#  11  Prize          541 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 50.8+ KB

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# Model            0
# Colour           0
# Memory           0
# RAM              0
# Battery_         0
# Rear Camera      0
# Front Camera     0
# AI Lens          0
# Mobile Height    0
# Processor_       0
# Prize            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        Unnamed: 0      Memory         RAM     Battery_     AI Lens  \
# count  541.000000  541.000000  541.000000   541.000000  541.000000
# mean   289.711645  110.550832    5.397412  4871.587800    0.062847
# std    182.359185   60.600694    1.984923   780.148862    0.242911
# min      0.000000   16.000000    2.000000   800.000000    0.000000
# 25%    135.000000   64.000000    4.000000  5000.000000    0.000000
# 50%    273.000000  128.000000    6.000000  5000.000000    0.000000
# 75%    434.000000  128.000000    8.000000  5000.000000    0.000000
# max    642.000000  256.000000    8.000000  7000.000000    1.000000
#
#        Mobile Height
# count     541.000000
# mean       16.431201
# std         2.523553
# min         4.500000
# 25%        16.510000
# 50%        16.710000
# 75%        16.940000
# max        41.940000

# %%
data=data.iloc[:,1:]

# %%
data
# Out:
#                      Model          Colour  Memory  RAM  Battery_ Rear Camera  \
# 0          Infinix SMART 7     Night Black      64    4      6000        13MP
# 1          Infinix SMART 7      Azure Blue      64    4      6000        13MP
# 2             MOTOROLA G32    Mineral Gray     128    8      5000        50MP
# 3                 POCO C50      Royal Blue      32    2      5000         8MP
# 4          Infinix HOT 30i        Marigold     128    8      5000        50MP
# ..                     ...             ...     ...  ...       ...         ...
# 536  SAMSUNG Galaxy S23 5G           Cream     256    8      3900        50MP
# 537               LAVA Z21            Cyan      32    2      3100         5MP
# 538         Tecno Spark 8T  Turquoise Cyan      64    4      5000        50MP
# 539  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000        50MP
# 540               OPPO A77        Sky Blue     128    4      5000        50MP
#
# ...

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data['Memory'])
# Out:
# (array([ 58.,   0., 169.,   0., 259.,   0.,   0.,   0.,   0.,  55.]),
#  array([ 16.,  40.,  64.,  88., 112., 136., 160., 184., 208., 232., 256.]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.distplot(data['RAM'])
# Out:
# C:\Users\Pragati\AppData\Local\Temp\ipykernel_12456\2266951621.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['RAM'])
# C:\Users\Pragati\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='RAM', ylabel='Density'>

# %%
data['Prize']=data['Prize'].str.replace(',','')
data['Prize']=pd.to_numeric(data['Prize'])

# %%
data['Prize']
# Out:
# 0       7299
# 1       7299
# 2      11999
# 3       5649
# 4       8999
#        ...
# 536    79999
# 537     5998
# 538     9990
# 539    38999
# 540    15999
# Name: Prize, Length: 541, dtype: int64

# %%
data
# Out:
#                      Model          Colour  Memory  RAM  Battery_ Rear Camera  \
# 0          Infinix SMART 7     Night Black      64    4      6000        13MP
# 1          Infinix SMART 7      Azure Blue      64    4      6000        13MP
# 2             MOTOROLA G32    Mineral Gray     128    8      5000        50MP
# 3                 POCO C50      Royal Blue      32    2      5000         8MP
# 4          Infinix HOT 30i        Marigold     128    8      5000        50MP
# ..                     ...             ...     ...  ...       ...         ...
# 536  SAMSUNG Galaxy S23 5G           Cream     256    8      3900        50MP
# 537               LAVA Z21            Cyan      32    2      3100         5MP
# 538         Tecno Spark 8T  Turquoise Cyan      64    4      5000        50MP
# 539  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000        50MP
# 540               OPPO A77        Sky Blue     128    4      5000        50MP
#
# ...

# %%
data.describe()
# Out:
#            Memory         RAM     Battery_     AI Lens  Mobile Height  \
# count  541.000000  541.000000   541.000000  541.000000     541.000000
# mean   110.550832    5.397412  4871.587800    0.062847      16.431201
# std     60.600694    1.984923   780.148862    0.242911       2.523553
# min     16.000000    2.000000   800.000000    0.000000       4.500000
# 25%     64.000000    4.000000  5000.000000    0.000000      16.510000
# 50%    128.000000    6.000000  5000.000000    0.000000      16.710000
# 75%    128.000000    8.000000  5000.000000    0.000000      16.940000
# max    256.000000    8.000000  7000.000000    1.000000      41.940000
#
#               Prize
# count    541.000000
# mean   16228.375231
# std    10793.588322
# min      920.000000
# 25%     9290.000000
# 50%    13499.000000
# 75%    19280.000000
# max    80999.000000

# %%
cor=data['Memory'].corr(data['Prize'])

# %%
cor
# Out:
# 0.5666597361136091

# %%
cor=data['RAM'].corr(data['Prize'])
cor
# Out:
# 0.5320244431179326

# %%
cor=data['Battery_'].corr(data['Prize'])
cor
# Out:
# -0.03429715107889537

# %%
cor=data['AI Lens'].corr(data['Prize'])
cor
# Out:
# -0.15369115583122994

# %%
cor=data['Mobile Height'].corr(data['Prize'])
cor
# Out:
# 0.17600894371500972

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X=data[['Memory','RAM']]

# %%
X
# Out:
#      Memory  RAM
# 0        64    4
# 1        64    4
# 2       128    8
# 3        32    2
# 4       128    8
# ..      ...  ...
# 536     256    8
# 537      32    2
# 538      64    4
# 539     128    8
# 540     128    4
#
# [541 rows x 2 columns]

# %%
y=data['Prize']

# %%
y
# Out:
# 0       7299
# 1       7299
# 2      11999
# 3       5649
# 4       8999
#        ...
# 536    79999
# 537     5998
# 538     9990
# 539    38999
# 540    15999
# Name: Prize, Length: 541, dtype: int64

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.20)

# %%
X_train
# Out:
#      Memory  RAM
# 489     256    6
# 302     128    8
# 20      128    8
# 63      128    4
# 128      64    4
# ..      ...  ...
# 413      64    4
# 363      64    4
# 233     128    6
# 323      64    4
# 306     128    6
#
# [432 rows x 2 columns]

# %%
X_test
# Out:
#      Memory  RAM
# 187      64    4
# 47      128    4
# 346     128    8
# 218      32    3
# 261     256    8
# ..      ...  ...
# 208      64    4
# 169      64    2
# 369     128    6
# 297      64    4
# 480      64    4
#
# [109 rows x 2 columns]

# %%
y_train
# Out:
# 489    49999
# 302    24999
# 20     15999
# 63     10499
# 128    12499
#        ...
# 413    16499
# 363    11999
# 233    13999
# 323     8999
# 306    21174
# Name: Prize, Length: 432, dtype: int64

# %%
y_test
# Out:
# 187    14999
# 47      9999
# 346    19280
# 218     7115
# 261    21999
#        ...
# 208    14999
# 169     6799
# 369    21499
# 297     9999
# 480     8999
# Name: Prize, Length: 109, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
Model = LinearRegression()
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= Model.predict(X_test)

# %%
y_pred
# Out:
# array([10648.94531848, 15130.00958125, 22064.68379284,  6674.74463419,
#        31026.81231839, 31026.81231839, 10648.94531848, 31026.81231839,
#        18597.34668705,  7181.60821268, 18597.34668705, 10648.94531848,
#         4941.07608129,  4941.07608129, 22064.68379284, 22064.68379284,
#        14116.28242427, 18597.34668705,  7181.60821268,  6674.74463419,
#        31026.81231839, 18597.34668705, 22064.68379284, 31026.81231839,
#        22064.68379284, 15130.00958125, 22064.68379284, 14116.28242427,
#        15130.00958125,  7181.60821268, 10648.94531848, 15130.00958125,
#        10648.94531848, 22064.68379284, 15130.00958125,  7181.60821268,
#        14116.28242427, 18597.34668705, 18597.34668705, 10648.94531848,
#        18597.34668705, 15130.00958125, 10648.94531848, 10648.94531848,
#        15130.00958125, 31026.81231839, 10648.94531848, 22064.68379284,
#        22064.68379284,  6674.74463419, 22064.68379284,  8915.27676558,
# ...

# %%
df=pd.DataFrame({'Actual':y_test,'Prediction':y_pred})
df
# Out:
#      Actual    Prediction
# 187   14999  10648.945318
# 47     9999  15130.009581
# 346   19280  22064.683793
# 218    7115   6674.744634
# 261   21999  31026.812318
# ..      ...           ...
# 208   14999  10648.945318
# 169    6799   7181.608213
# 369   21499  18597.346687
# 297    9999  10648.945318
# 480    8999  10648.945318
#
# [109 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
